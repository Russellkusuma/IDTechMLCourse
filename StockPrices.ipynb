# %%
# Import
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
# Import data
data = pd.read_csv('./Desktop/Russell_PycharmML/data_stocks.csv')
# Drop date variable
data = data.drop(['DATE'], 1)
# Dimensions of dataset
n = data.shape[0]
p = data.shape[1]
# Make data a numpy array
data = data.values

print(data.shape)
# Out:
# (41266, 501)

# %%
#Printing the Stock prices of
plt.plot(data[:,0])
plt.xlabel('Index')
plt.ylabel('Stock Prices')
plt.title('Stock stuff')
plt.show()
